# %% [raw]
# !git clone https://github.com/masa-ita/keras-composer.git

# %% [raw]
# !mkdir keras-composer/weights

# %%
# !pip install music21
# Out:
# Collecting music21
#   Downloading https://files.pythonhosted.org/packages/4a/db/317c21f4b5b970c3bfb5ff321e333059faf775621ae6433abcd4c68c69db/music21-5.3.0.tar.gz (18.0MB)
#     100% |████████████████████████████████| 18.0MB 86kB/s
# Building wheels for collected packages: music21
#   Running setup.py bdist_wheel for music21 ... done
#   Stored in directory: /root/.cache/pip/wheels/53/8b/a6/be1921c60a68f0bea31c6b6a0a7b125badd61294d6a694407f
# Successfully built music21
# Installing collected packages: music21
# Successfully installed music21-5.3.0
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import keras
from keras import objectives, backend as K
from keras.layers import Bidirectional, Dense, Embedding, Input, Lambda
from keras.layers import LSTM, CuDNNLSTM, RepeatVector, TimeDistributed, Dropout
from keras.models import Model
from keras.callbacks import ModelCheckpoint, CSVLogger
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
import numpy as np
import os
import glob
import pickle
from music21 import converter, instrument, note, chord, stream
# Out:
# Using TensorFlow backend.

# %%
MAX_LENGTH = 300

# %%
class VAE(object):
    def __init__(self, vocab_size=500, max_length=300, latent_rep_size=64):
        self.encoder = None
        self.decoder = None
        self.autoencoder = None

        x = Input(shape=(max_length, vocab_size))

        vae_loss, encoded = self._build_encoder(x, latent_rep_size=latent_rep_size, max_length=max_length)
        self.encoder = Model(inputs=x, outputs=encoded)
        encoder_out = self.encoder(x)

        encoded_input = Input(shape=(latent_rep_size,))

        decoded = self._build_decoder(encoded_input, vocab_size, max_length)
        self.decoder = Model(encoded_input, decoded)
        
        decoder_out = self.decoder(encoder_out)

        self.autoencoder = Model(inputs=x, outputs=decoder_out)
        self.autoencoder.compile(optimizer='Adam',
                                 loss=vae_loss,
                                 metrics=['accuracy'])
        
    def _build_encoder(self, x, latent_rep_size=64, max_length=300, epsilon_std=0.01):
        h = CuDNNLSTM(512, return_sequences=False, name='lstm_1')(x)
        h = Dropout(0.2)(h)
        h = Dense(256, activation='relu', name='dense_1')(h)

        def sampling(args):
            z_mean_, z_log_var_ = args
            batch_size = K.shape(z_mean_)[0]
            epsilon = K.random_normal(shape=(batch_size, latent_rep_size), mean=0., stddev=epsilon_std)
            return z_mean_ + K.exp(z_log_var_ / 2) * epsilon

        z_mean = Dense(latent_rep_size, name='z_mean', activation='linear')(h)
        z_log_var = Dense(latent_rep_size, name='z_log_var', activation='linear')(h)
    
        def vae_loss(x, x_decoded_mean):
            x = K.flatten(x)
            x_decoded_mean = K.flatten(x_decoded_mean)
            xent_loss = max_length * objectives.binary_crossentropy(x, x_decoded_mean)
            kl_loss = - 0.5 * K.mean(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
            return xent_loss + kl_loss

        return (vae_loss, Lambda(sampling, output_shape=(latent_rep_size,), name='lambda')([z_mean, z_log_var]))

    def _build_decoder(self, encoded, vocab_size, max_length):
        repeated_context = RepeatVector(max_length)(encoded)
    
        h = CuDNNLSTM(512, return_sequences=True, name='dec_lstm_1')(repeated_context)
    
        decoded = TimeDistributed(Dense(vocab_size, activation='softmax'), name='decoded_mean')(h)
    
        return decoded

# %%
def parse_midi_files(dir):
    notes = []
    songs = []

    for file in glob.glob(os.path.join(dir, '*.mid')):
        song = []
        midi = converter.parse(file)

        print("Parsing %s" % file)

        notes_to_parse = None

        try: # file has instrument parts
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse() 
        except: # file has notes in a flat structure
            notes_to_parse = midi.flat.notes

        for element in notes_to_parse:
            if isinstance(element, note.Note):
                song.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                song.append('.'.join(str(n) for n in element.normalOrder))
        songs.append(song)
        notes += song

    return notes, songs

# %%
notes, songs = parse_midi_files('/root/userspace/keras-composer/midi_songs')
# Out:
# Parsing /root/userspace/keras-composer/midi_songs/bwv782.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv773.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv786.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv777.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv784.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv775.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv780.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv779.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv783.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv774.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv778.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv785.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv776.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv781.mid
# Parsing /root/userspace/keras-composer/midi_songs/bwv772.mid

# %%
pitchnames = sorted(set(notes))
n_vocab = len(pitchnames)

note_to_int = dict((note, number) for number, note in enumerate(pitchnames))
int_to_note = dict([[number, note] for note, number in note_to_int.items()])

encoded_songs = [[note_to_int[note] for note in song] for song in songs]

padded_songs = pad_sequences(encoded_songs, maxlen=MAX_LENGTH)

# %%
temp = np.zeros((padded_songs.shape[0], MAX_LENGTH, n_vocab))
temp[np.expand_dims(np.arange(padded_songs.shape[0]), axis=0).reshape(padded_songs.shape[0], 1), 
           np.repeat(np.array([np.arange(MAX_LENGTH)]), padded_songs.shape[0], axis=0), padded_songs] = 1

one_hot_encoded_songs = temp

# %%
def create_model_checkpoint(dir, model_name):
    filepath = dir + '/' + \
               model_name + "-{epoch:02d}-{acc:.2f}-{loss:.2f}.h5"
    directory = os.path.dirname(filepath)

    try:
        os.stat(directory)
    except:
        os.mkdir(directory)

    checkpointer = ModelCheckpoint(filepath=filepath,
                                                              monitor='loss',
                                                              verbose=1,
                                                              save_best_only=True)

    return checkpointer

# %%
model = VAE(vocab_size=n_vocab, latent_rep_size=2, max_length=MAX_LENGTH)

# %%
checkpointer = create_model_checkpoint('/root/userspace/keras-composer/vae_output', 'music_vae')
csv_logger = CSVLogger(os.path.join('/root/userspace/keras-composer/vae_output', 'music_vae_log.csv'))

history = model.autoencoder.fit(x=one_hot_encoded_songs, 
                                                        y=one_hot_encoded_songs,
                                                        batch_size=1, 
                                                        epochs=10000, 
                                                        callbacks=[checkpointer, csv_logger], 
                                                        verbose=0)
# Out:
# Epoch 00001: loss improved from inf to 13.05794, saving model to /root/userspace/keras-composer/vae_output/music_vae-01-0.03-13.06.h5
# Epoch 00002: loss improved from 13.05794 to 12.54065, saving model to /root/userspace/keras-composer/vae_output/music_vae-02-0.03-12.54.h5
# Epoch 00003: loss improved from 12.54065 to 12.33448, saving model to /root/userspace/keras-composer/vae_output/music_vae-03-0.04-12.33.h5
# Epoch 00004: loss improved from 12.33448 to 12.29151, saving model to /root/userspace/keras-composer/vae_output/music_vae-04-0.04-12.29.h5
# Epoch 00005: loss improved from 12.29151 to 12.28153, saving model to /root/userspace/keras-composer/vae_output/music_vae-05-0.04-12.28.h5
# Epoch 00006: loss did not improve
# Epoch 00007: loss did not improve
# Epoch 00008: loss improved from 12.28153 to 12.27743, saving model to /root/userspace/keras-composer/vae_output/music_vae-08-0.05-12.28.h5
# Epoch 00009: loss improved from 12.27743 to 12.25689, saving model to /root/userspace/keras-composer/vae_output/music_vae-09-0.04-12.26.h5
# Epoch 00010: loss did not improve
# Epoch 00011: loss did not improve
# Epoch 00012: loss improved from 12.25689 to 12.24928, saving model to /root/userspace/keras-composer/vae_output/music_vae-12-0.05-12.25.h5
# Epoch 00013: loss did not improve
# Epoch 00014: loss did not improve
# Epoch 00015: loss did not improve
# Epoch 00016: loss improved from 12.24928 to 12.24431, saving model to /root/userspace/keras-composer/vae_output/music_vae-16-0.05-12.24.h5
# Epoch 00017: loss improved from 12.24431 to 12.23107, saving model to /root/userspace/keras-composer/vae_output/music_vae-17-0.05-12.23.h5
# Epoch 00018: loss improved from 12.23107 to 12.22990, saving model to /root/userspace/keras-composer/vae_output/music_vae-18-0.05-12.23.h5
# Epoch 00019: loss did not improve
# Epoch 00020: loss improved from 12.22990 to 12.22662, saving model to /root/userspace/keras-composer/vae_output/music_vae-20-0.05-12.23.h5
# Epoch 00021: loss did not improve
# Epoch 00022: loss improved from 12.22662 to 12.21898, saving model to /root/userspace/keras-composer/vae_output/music_vae-22-0.04-12.22.h5
# Epoch 00023: loss did not improve
# Epoch 00024: loss did not improve
# Epoch 00025: loss did not improve
# Epoch 00026: loss improved from 12.21898 to 12.21460, saving model to /root/userspace/keras-composer/vae_output/music_vae-26-0.05-12.21.h5
# Epoch 00027: loss did not improve
# Epoch 00028: loss improved from 12.21460 to 12.20622, saving model to /root/userspace/keras-composer/vae_output/music_vae-28-0.05-12.21.h5
# Epoch 00029: loss did not improve
# Epoch 00030: loss did not improve
# Epoch 00031: loss improved from 12.20622 to 12.20464, saving model to /root/userspace/keras-composer/vae_output/music_vae-31-0.05-12.20.h5
# Epoch 00032: loss did not improve
# Epoch 00033: loss did not improve
# Epoch 00034: loss did not improve
# Epoch 00035: loss did not improve
# Epoch 00036: loss improved from 12.20464 to 12.18761, saving model to /root/userspace/keras-composer/vae_output/music_vae-36-0.05-12.19.h5
# Epoch 00037: loss did not improve
# Epoch 00038: loss did not improve
# Epoch 00039: loss improved from 12.18761 to 12.17745, saving model to /root/userspace/keras-composer/vae_output/music_vae-39-0.05-12.18.h5
# Epoch 00040: loss did not improve
# Epoch 00041: loss did not improve
# Epoch 00042: loss improved from 12.17745 to 12.14643, saving model to /root/userspace/keras-composer/vae_output/music_vae-42-0.05-12.15.h5
# Epoch 00043: loss did not improve
# Epoch 00044: loss improved from 12.14643 to 12.10933, saving model to /root/userspace/keras-composer/vae_output/music_vae-44-0.05-12.11.h5
# Epoch 00045: loss did not improve
# Epoch 00046: loss did not improve
# Epoch 00047: loss did not improve
# Epoch 00048: loss did not improve
# Epoch 00049: loss did not improve
# Epoch 00050: loss did not improve
# Epoch 00051: loss did not improve
# Epoch 00052: loss did not improve
# Epoch 00053: loss did not improve
# Epoch 00054: loss did not improve
# Epoch 00055: loss did not improve
# Epoch 00056: loss did not improve
# Epoch 00057: loss did not improve
# Epoch 00058: loss did not improve
# Epoch 00059: loss did not improve
# Epoch 00060: loss did not improve
# Epoch 00061: loss did not improve
# Epoch 00062: loss did not improve
# Epoch 00063: loss did not improve
# Epoch 00064: loss did not improve
# Epoch 00065: loss did not improve
# Epoch 00066: loss did not improve
# Epoch 00067: loss did not improve
# Epoch 00068: loss did not improve
# Epoch 00069: loss improved from 12.10933 to 12.09950, saving model to /root/userspace/keras-composer/vae_output/music_vae-69-0.05-12.10.h5
# Epoch 00070: loss did not improve
# Epoch 00071: loss did not improve
# Epoch 00072: loss improved from 12.09950 to 12.09358, saving model to /root/userspace/keras-composer/vae_output/music_vae-72-0.05-12.09.h5
# Epoch 00073: loss improved from 12.09358 to 12.08210, saving model to /root/userspace/keras-composer/vae_output/music_vae-73-0.05-12.08.h5
# Epoch 00074: loss did not improve
# Epoch 00075: loss improved from 12.08210 to 12.07457, saving model to /root/userspace/keras-composer/vae_output/music_vae-75-0.04-12.07.h5
# Epoch 00076: loss did not improve
# Epoch 00077: loss did not improve
# Epoch 00078: loss improved from 12.07457 to 12.06714, saving model to /root/userspace/keras-composer/vae_output/music_vae-78-0.05-12.07.h5
# Epoch 00079: loss improved from 12.06714 to 12.06467, saving model to /root/userspace/keras-composer/vae_output/music_vae-79-0.05-12.06.h5
# Epoch 00080: loss did not improve
# Epoch 00081: loss improved from 12.06467 to 12.05597, saving model to /root/userspace/keras-composer/vae_output/music_vae-81-0.05-12.06.h5
# Epoch 00082: loss improved from 12.05597 to 12.04454, saving model to /root/userspace/keras-composer/vae_output/music_vae-82-0.05-12.04.h5
# Epoch 00083: loss did not improve
# Epoch 00084: loss improved from 12.04454 to 12.03789, saving model to /root/userspace/keras-composer/vae_output/music_vae-84-0.05-12.04.h5
# Epoch 00085: loss improved from 12.03789 to 12.03174, saving model to /root/userspace/keras-composer/vae_output/music_vae-85-0.05-12.03.h5
# Epoch 00086: loss improved from 12.03174 to 12.02088, saving model to /root/userspace/keras-composer/vae_output/music_vae-86-0.05-12.02.h5
# Epoch 00087: loss improved from 12.02088 to 12.00830, saving model to /root/userspace/keras-composer/vae_output/music_vae-87-0.05-12.01.h5
# Epoch 00088: loss did not improve
# Epoch 00089: loss did not improve
# Epoch 00090: loss did not improve
# Epoch 00091: loss did not improve
# Epoch 00092: loss improved from 12.00830 to 11.99109, saving model to /root/userspace/keras-composer/vae_output/music_vae-92-0.05-11.99.h5
# Epoch 00093: loss improved from 11.99109 to 11.97720, saving model to /root/userspace/keras-composer/vae_output/music_vae-93-0.05-11.98.h5
# Epoch 00094: loss did not improve
# Epoch 00095: loss improved from 11.97720 to 11.97376, saving model to /root/userspace/keras-composer/vae_output/music_vae-95-0.05-11.97.h5
# Epoch 00096: loss did not improve
# Epoch 00097: loss improved from 11.97376 to 11.95330, saving model to /root/userspace/keras-composer/vae_output/music_vae-97-0.05-11.95.h5
# Epoch 00098: loss did not improve
# Epoch 00099: loss did not improve
# Epoch 00100: loss did not improve
# Epoch 00101: loss improved from 11.95330 to 11.95029, saving model to /root/userspace/keras-composer/vae_output/music_vae-101-0.05-11.95.h5
# Epoch 00102: loss improved from 11.95029 to 11.94137, saving model to /root/userspace/keras-composer/vae_output/music_vae-102-0.05-11.94.h5
# Epoch 00103: loss improved from 11.94137 to 11.93431, saving model to /root/userspace/keras-composer/vae_output/music_vae-103-0.05-11.93.h5
# Epoch 00104: loss improved from 11.93431 to 11.91411, saving model to /root/userspace/keras-composer/vae_output/music_vae-104-0.06-11.91.h5
# Epoch 00105: loss did not improve
# Epoch 00106: loss did not improve
# Epoch 00107: loss did not improve
# Epoch 00108: loss did not improve
# Epoch 00109: loss improved from 11.91411 to 11.90277, saving model to /root/userspace/keras-composer/vae_output/music_vae-109-0.05-11.90.h5
# Epoch 00110: loss did not improve
# Epoch 00111: loss improved from 11.90277 to 11.90041, saving model to /root/userspace/keras-composer/vae_output/music_vae-111-0.06-11.90.h5
# Epoch 00112: loss improved from 11.90041 to 11.88885, saving model to /root/userspace/keras-composer/vae_output/music_vae-112-0.05-11.89.h5
# Epoch 00113: loss did not improve
# Epoch 00114: loss improved from 11.88885 to 11.88588, saving model to /root/userspace/keras-composer/vae_output/music_vae-114-0.06-11.89.h5
# Epoch 00115: loss improved from 11.88588 to 11.88452, saving model to /root/userspace/keras-composer/vae_output/music_vae-115-0.05-11.88.h5
# Epoch 00116: loss did not improve
# Epoch 00117: loss improved from 11.88452 to 11.88204, saving model to /root/userspace/keras-composer/vae_output/music_vae-117-0.06-11.88.h5
# Epoch 00118: loss improved from 11.88204 to 11.87660, saving model to /root/userspace/keras-composer/vae_output/music_vae-118-0.06-11.88.h5
# Epoch 00119: loss improved from 11.87660 to 11.86363, saving model to /root/userspace/keras-composer/vae_output/music_vae-119-0.06-11.86.h5
# Epoch 00120: loss improved from 11.86363 to 11.84256, saving model to /root/userspace/keras-composer/vae_output/music_vae-120-0.06-11.84.h5
# Epoch 00121: loss improved from 11.84256 to 11.83136, saving model to /root/userspace/keras-composer/vae_output/music_vae-121-0.05-11.83.h5
# Epoch 00122: loss did not improve
# Epoch 00123: loss improved from 11.83136 to 11.82949, saving model to /root/userspace/keras-composer/vae_output/music_vae-123-0.05-11.83.h5
# Epoch 00124: loss did not improve
# Epoch 00125: loss did not improve
# Epoch 00126: loss did not improve
# Epoch 00127: loss improved from 11.82949 to 11.80777, saving model to /root/userspace/keras-composer/vae_output/music_vae-127-0.05-11.81.h5
# Epoch 00128: loss did not improve
# Epoch 00129: loss did not improve
# Epoch 00130: loss did not improve
# Epoch 00131: loss did not improve
# Epoch 00132: loss did not improve
# Epoch 00133: loss improved from 11.80777 to 11.80292, saving model to /root/userspace/keras-composer/vae_output/music_vae-133-0.06-11.80.h5
# Epoch 00134: loss improved from 11.80292 to 11.77804, saving model to /root/userspace/keras-composer/vae_output/music_vae-134-0.06-11.78.h5
# Epoch 00135: loss did not improve
# Epoch 00136: loss improved from 11.77804 to 11.77684, saving model to /root/userspace/keras-composer/vae_output/music_vae-136-0.05-11.78.h5
# Epoch 00137: loss improved from 11.77684 to 11.76989, saving model to /root/userspace/keras-composer/vae_output/music_vae-137-0.06-11.77.h5
# Epoch 00138: loss improved from 11.76989 to 11.76071, saving model to /root/userspace/keras-composer/vae_output/music_vae-138-0.05-11.76.h5
# Epoch 00139: loss did not improve
# Epoch 00140: loss did not improve
# Epoch 00141: loss did not improve
# Epoch 00142: loss improved from 11.76071 to 11.75681, saving model to /root/userspace/keras-composer/vae_output/music_vae-142-0.06-11.76.h5
# Epoch 00143: loss did not improve
# Epoch 00144: loss improved from 11.75681 to 11.71760, saving model to /root/userspace/keras-composer/vae_output/music_vae-144-0.06-11.72.h5
# Epoch 00145: loss improved from 11.71760 to 11.70503, saving model to /root/userspace/keras-composer/vae_output/music_vae-145-0.06-11.71.h5
# Epoch 00146: loss did not improve
# Epoch 00147: loss did not improve
# Epoch 00148: loss improved from 11.70503 to 11.69475, saving model to /root/userspace/keras-composer/vae_output/music_vae-148-0.06-11.69.h5
# Epoch 00149: loss did not improve
# Epoch 00150: loss improved from 11.69475 to 11.69442, saving model to /root/userspace/keras-composer/vae_output/music_vae-150-0.06-11.69.h5
# Epoch 00151: loss improved from 11.69442 to 11.68052, saving model to /root/userspace/keras-composer/vae_output/music_vae-151-0.06-11.68.h5
# Epoch 00152: loss improved from 11.68052 to 11.65453, saving model to /root/userspace/keras-composer/vae_output/music_vae-152-0.06-11.65.h5
# Epoch 00153: loss did not improve
# Epoch 00154: loss did not improve
# Epoch 00155: loss improved from 11.65453 to 11.63602, saving model to /root/userspace/keras-composer/vae_output/music_vae-155-0.06-11.64.h5
# Epoch 00156: loss did not improve
# Epoch 00157: loss improved from 11.63602 to 11.62521, saving model to /root/userspace/keras-composer/vae_output/music_vae-157-0.06-11.63.h5
# Epoch 00158: loss did not improve
# Epoch 00159: loss improved from 11.62521 to 11.60684, saving model to /root/userspace/keras-composer/vae_output/music_vae-159-0.06-11.61.h5
# Epoch 00160: loss did not improve
# Epoch 00161: loss did not improve
# Epoch 00162: loss did not improve
# Epoch 00163: loss improved from 11.60684 to 11.59023, saving model to /root/userspace/keras-composer/vae_output/music_vae-163-0.06-11.59.h5
# Epoch 00164: loss improved from 11.59023 to 11.57183, saving model to /root/userspace/keras-composer/vae_output/music_vae-164-0.06-11.57.h5
# Epoch 00165: loss improved from 11.57183 to 11.57114, saving model to /root/userspace/keras-composer/vae_output/music_vae-165-0.06-11.57.h5
# Epoch 00166: loss did not improve
# Epoch 00167: loss did not improve
# Epoch 00168: loss did not improve
# Epoch 00169: loss improved from 11.57114 to 11.55975, saving model to /root/userspace/keras-composer/vae_output/music_vae-169-0.06-11.56.h5
# Epoch 00170: loss improved from 11.55975 to 11.55487, saving model to /root/userspace/keras-composer/vae_output/music_vae-170-0.06-11.55.h5
# Epoch 00171: loss improved from 11.55487 to 11.54985, saving model to /root/userspace/keras-composer/vae_output/music_vae-171-0.06-11.55.h5
# Epoch 00172: loss improved from 11.54985 to 11.54179, saving model to /root/userspace/keras-composer/vae_output/music_vae-172-0.06-11.54.h5
# Epoch 00173: loss improved from 11.54179 to 11.53918, saving model to /root/userspace/keras-composer/vae_output/music_vae-173-0.06-11.54.h5
# Epoch 00174: loss improved from 11.53918 to 11.51355, saving model to /root/userspace/keras-composer/vae_output/music_vae-174-0.06-11.51.h5
# Epoch 00175: loss did not improve
# Epoch 00176: loss improved from 11.51355 to 11.46898, saving model to /root/userspace/keras-composer/vae_output/music_vae-176-0.06-11.47.h5
# Epoch 00177: loss did not improve
# Epoch 00178: loss did not improve
# Epoch 00179: loss improved from 11.46898 to 11.45825, saving model to /root/userspace/keras-composer/vae_output/music_vae-179-0.06-11.46.h5
# Epoch 00180: loss did not improve
# Epoch 00181: loss improved from 11.45825 to 11.44067, saving model to /root/userspace/keras-composer/vae_output/music_vae-181-0.06-11.44.h5
# Epoch 00182: loss improved from 11.44067 to 11.42448, saving model to /root/userspace/keras-composer/vae_output/music_vae-182-0.06-11.42.h5
# Epoch 00183: loss did not improve
# Epoch 00184: loss did not improve
# Epoch 00185: loss improved from 11.42448 to 11.39165, saving model to /root/userspace/keras-composer/vae_output/music_vae-185-0.07-11.39.h5
# Epoch 00186: loss improved from 11.39165 to 11.35373, saving model to /root/userspace/keras-composer/vae_output/music_vae-186-0.07-11.35.h5
# Epoch 00187: loss did not improve
# Epoch 00188: loss did not improve
# Epoch 00189: loss did not improve
# Epoch 00190: loss improved from 11.35373 to 11.30351, saving model to /root/userspace/keras-composer/vae_output/music_vae-190-0.07-11.30.h5
# Epoch 00191: loss did not improve
# Epoch 00192: loss did not improve
# Epoch 00193: loss did not improve
# Epoch 00194: loss did not improve
# Epoch 00195: loss improved from 11.30351 to 11.30178, saving model to /root/userspace/keras-composer/vae_output/music_vae-195-0.08-11.30.h5
# Epoch 00196: loss improved from 11.30178 to 11.27206, saving model to /root/userspace/keras-composer/vae_output/music_vae-196-0.08-11.27.h5
# Epoch 00197: loss did not improve
# Epoch 00198: loss improved from 11.27206 to 11.27069, saving model to /root/userspace/keras-composer/vae_output/music_vae-198-0.08-11.27.h5
# Epoch 00199: loss improved from 11.27069 to 11.19301, saving model to /root/userspace/keras-composer/vae_output/music_vae-199-0.08-11.19.h5
# Epoch 00200: loss improved from 11.19301 to 11.17838, saving model to /root/userspace/keras-composer/vae_output/music_vae-200-0.08-11.18.h5
# Epoch 00201: loss improved from 11.17838 to 11.17780, saving model to /root/userspace/keras-composer/vae_output/music_vae-201-0.08-11.18.h5
# Epoch 00202: loss did not improve
# Epoch 00203: loss did not improve
# Epoch 00204: loss did not improve
# Epoch 00205: loss did not improve
# Epoch 00206: loss improved from 11.17780 to 11.13796, saving model to /root/userspace/keras-composer/vae_output/music_vae-206-0.08-11.14.h5
# Epoch 00207: loss improved from 11.13796 to 11.13721, saving model to /root/userspace/keras-composer/vae_output/music_vae-207-0.08-11.14.h5
# Epoch 00208: loss improved from 11.13721 to 11.09703, saving model to /root/userspace/keras-composer/vae_output/music_vae-208-0.08-11.10.h5
# Epoch 00209: loss did not improve
# Epoch 00210: loss improved from 11.09703 to 11.03874, saving model to /root/userspace/keras-composer/vae_output/music_vae-210-0.09-11.04.h5
# Epoch 00211: loss did not improve
# Epoch 00212: loss improved from 11.03874 to 11.00022, saving model to /root/userspace/keras-composer/vae_output/music_vae-212-0.09-11.00.h5
# Epoch 00213: loss improved from 11.00022 to 10.99068, saving model to /root/userspace/keras-composer/vae_output/music_vae-213-0.09-10.99.h5
# Epoch 00214: loss improved from 10.99068 to 10.97207, saving model to /root/userspace/keras-composer/vae_output/music_vae-214-0.09-10.97.h5
# Epoch 00215: loss did not improve
# Epoch 00216: loss did not improve
# Epoch 00217: loss did not improve
# Epoch 00218: loss did not improve
# Epoch 00219: loss did not improve
# Epoch 00220: loss did not improve
# Epoch 00221: loss improved from 10.97207 to 10.96607, saving model to /root/userspace/keras-composer/vae_output/music_vae-221-0.09-10.97.h5
# Epoch 00222: loss improved from 10.96607 to 10.96012, saving model to /root/userspace/keras-composer/vae_output/music_vae-222-0.09-10.96.h5
# Epoch 00223: loss improved from 10.96012 to 10.90583, saving model to /root/userspace/keras-composer/vae_output/music_vae-223-0.09-10.91.h5
# Epoch 00224: loss improved from 10.90583 to 10.90241, saving model to /root/userspace/keras-composer/vae_output/music_vae-224-0.09-10.90.h5
# Epoch 00225: loss did not improve
# Epoch 00226: loss improved from 10.90241 to 10.87913, saving model to /root/userspace/keras-composer/vae_output/music_vae-226-0.09-10.88.h5
# Epoch 00227: loss did not improve
# Epoch 00228: loss did not improve
# Epoch 00229: loss did not improve
# Epoch 00230: loss improved from 10.87913 to 10.83303, saving model to /root/userspace/keras-composer/vae_output/music_vae-230-0.09-10.83.h5
# Epoch 00231: loss improved from 10.83303 to 10.81269, saving model to /root/userspace/keras-composer/vae_output/music_vae-231-0.10-10.81.h5
# Epoch 00232: loss did not improve
# Epoch 00233: loss did not improve
# Epoch 00234: loss did not improve
# Epoch 00235: loss did not improve
# Epoch 00236: loss improved from 10.81269 to 10.79478, saving model to /root/userspace/keras-composer/vae_output/music_vae-236-0.09-10.79.h5
# Epoch 00237: loss did not improve
# Epoch 00238: loss did not improve
# Epoch 00239: loss improved from 10.79478 to 10.76551, saving model to /root/userspace/keras-composer/vae_output/music_vae-239-0.10-10.77.h5
# Epoch 00240: loss improved from 10.76551 to 10.74114, saving model to /root/userspace/keras-composer/vae_output/music_vae-240-0.10-10.74.h5
# Epoch 00241: loss did not improve
# Epoch 00242: loss did not improve
# Epoch 00243: loss did not improve
# Epoch 00244: loss did not improve
# Epoch 00245: loss did not improve
# Epoch 00246: loss did not improve
# Epoch 00247: loss did not improve
# Epoch 00248: loss did not improve
# Epoch 00249: loss did not improve
# Epoch 00250: loss did not improve
# Epoch 00251: loss did not improve
# Epoch 00252: loss did not improve
# Epoch 00253: loss did not improve
# Epoch 00254: loss did not improve
# Epoch 00255: loss did not improve
# Epoch 02409: loss did not improve
# Epoch 02410: loss did not improve
# Epoch 02411: loss did not improve
# Epoch 02412: loss did not improve
# Epoch 02413: loss did not improve
# Epoch 02414: loss did not improve
# Epoch 02415: loss did not improve
# Epoch 02416: loss did not improve
# Epoch 02417: loss did not improve
# Epoch 02418: loss did not improve
# Epoch 02419: loss did not improve
# Epoch 02420: loss did not improve
# Epoch 02421: loss did not improve
# Epoch 02422: loss did not improve
# Epoch 02423: loss did not improve
# Epoch 02424: loss did not improve
# Epoch 02425: loss did not improve
# Epoch 02426: loss did not improve
# Epoch 02427: loss did not improve
# Epoch 02428: loss did not improve
# Epoch 02429: loss did not improve
# Epoch 02430: loss did not improve
# Epoch 02431: loss did not improve
# Epoch 02432: loss did not improve
# Epoch 02433: loss did not improve
# Epoch 02434: loss did not improve
# Epoch 02435: loss did not improve
# Epoch 02436: loss did not improve
# Epoch 02437: loss did not improve
# Epoch 02438: loss did not improve
# Epoch 02439: loss did not improve
# Epoch 02440: loss did not improve
# Epoch 02441: loss did not improve
# Epoch 02442: loss did not improve
# Epoch 02443: loss did not improve
# Epoch 02444: loss did not improve
# Epoch 02445: loss did not improve
# Epoch 02446: loss did not improve
# Epoch 02447: loss did not improve
# Epoch 02448: loss did not improve
# Epoch 02449: loss did not improve
# Epoch 02450: loss did not improve
# Epoch 02451: loss did not improve
# Epoch 02452: loss did not improve
# Epoch 02453: loss did not improve
# Epoch 02454: loss did not improve
# Epoch 02455: loss did not improve
# Epoch 02456: loss did not improve
# Epoch 02457: loss did not improve
# Epoch 02458: loss did not improve
# Epoch 02459: loss did not improve
# Epoch 02460: loss did not improve
# Epoch 02461: loss did not improve
# Epoch 02462: loss did not improve
# Epoch 02463: loss did not improve
# Epoch 02464: loss did not improve
# Epoch 02465: loss did not improve
# Epoch 02466: loss did not improve
# Epoch 02467: loss did not improve
# Epoch 02468: loss did not improve
# Epoch 02469: loss did not improve
# Epoch 02470: loss did not improve
# Epoch 02471: loss did not improve
# Epoch 02472: loss did not improve
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-aa986eeaa4b3> in <module>()
#       7                                                         epochs=10000,
#       8                                                         callbacks=[checkpointer, csv_logger],
# ----> 9                                                         verbose=0)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1655                               initial_epoch=initial_epoch,
#    1656                               steps_per_epoch=steps_per_epoch,
# -> 1657                               validation_steps=validation_steps)
#    1658
#    1659     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
model.autoencoder.load_weights('/root/userspace/keras-composer/vae_output/music_vae-827-0.48-5.67.h5')

# %%
prediction_output = model.autoencoder.predict(one_hot_encoded_songs[np.newaxis, 0])

# %%
prediction_indices = np.argmax(prediction_output, axis=2)

prediction_song = [int_to_note[index] for index in prediction_indices[0]]
print(prediction_song)
# Out:
# ['5.11', '1.4', 'F4', 'G4', 'D5', 'G#4', 'C5', 'D5', 'E3', 'C5', 'D5', 'G4', 'C#5', 'D4', 'D5', 'E5', 'D5', 'E-4', 'E-5', 'F5', 'E-5', 'F4', 'D5', 'E-5', 'G3', 'D5', 'F4', 'E-4', 'B-4', 'A4', 'E-4', 'C5', 'F3', 'E-3', 'D3', 'E-3', 'D5', 'C3', 'E4', 'D5', '8.0', '7.10', 'C5', 'G#4', 'F3', 'A4', 'G3', 'F3', 'D5', 'E-3', 'C5', 'E-5', 'F3', 'C5', 'E-5', '11.2', '9.0', '3.9', 'B4', 'A4', 'B2', '9.0', '11.2', '0.3', 'F4', 'G3', 'E-5', 'E-3', '11.2', 'G#3', '11.2', '0.3', 'G3', '3.7', '8.0', 'F3', 'G5', 'A2', 'E-3', 'G2', 'B4', 'E-3', 'F3', '5.8', 'G2', '2.5', 'E-3', 'C5', '7.10', 'D3', 'C5', 'G#2', 'B-2', 'A2', 'A2', 'D5', 'A4', '7.10', '5.9', '3.7', '7.9', 'F4', 'G3', 'F3', 'B2', 'C#5', 'F5', '0.3', 'C#3', '9.0', 'B-2', 'C#5', 'C#3', 'C5', 'C#5', 'F3', 'E-5', 'F#5', 'A3', 'C3', 'B2', 'D5', '9.0', 'B-3', 'B-4', 'G#4', 'F4', 'G#3', 'C3', 'B-5', 'F3', 'G3', 'G#5', 'E-3', 'G5', 'D4', '1.3', '0.1', 'C5', 'C5', 'C5', 'C5', 'C4', '0', 'C5', '0.3', '0.3', 'E-5', 'E-5', 'D5', 'G#3', 'C#4', 'B-3', 'G#5', 'G5', '7.0', '2.5', '3', 'G3', 'G3', 'G5', 'C4', 'F5', 'B-3', 'C#5', '10.3', 'C#4', '3.7', 'C4', 'B-3', 'G5', 'F5', 'F5', 'G5', 'D4', '5.10', '0.3', '0.3', '10.2', 'E-5', 'C#5', 'C5', '8.1', '9.0', 'F#5', 'B-3', 'E-4', 'E4', 'F5', 'F5', 'F5', '10.2', '3.7', 'E-5', 'E-5', 'C#4', 'C#5', 'C5', 'C5', 'C5', '7.10', '7.10', '7.10', '4.7', '4.7', 'B-4', 'B-4', 'B-4', 'B-4', 'B-4', 'G4', 'G4', 'G4', 'G4', '5.8', '7.10', '10.1', '8.0', '8.0', '10', '10', 'G#4', 'G#4', 'G#4', 'G#4', 'B-4', 'B-4', 'G3', 'G3', 'F3', 'C#5', 'C#5', 'C#5', 'G4', 'G4', 'C3', 'C3', 'A4', 'B-4', 'B-4', 'B-4', 'B-4', 'B-4', 'B-4', 'G#2', 'G#2', 'E5', 'E5', 'E5', 'E5', 'E5', 'G5', '3.6', '3.6', '2.7', '5.8', '5.8', 'G2', '7.10', 'D5', 'B-3', 'F2', 'F2', 'F2', 'F2', 'C5', 'C5', 'C5', 'C5', 'C5', 'G#4', 'G#4', 'B-4', 'B-4', '0.2', '4.10', '5.8', '4.7', '4.7', '4.7', 'C3', 'C3', 'C3', 'C5', 'G4', 'G4', 'G4', 'G4', 'G4', 'G#4', 'G#4', 'G#4', 'G#4', 'G4', 'G4', 'G4', 'G4', 'G4', '5', '7']

# %%
def create_midi(prediction_output, file_path):
    """ convert the output from the prediction to notes and create a midi file
        from the notes """
    offset = 0
    output_notes = []

    # create note and chord objects based on the values generated by the model
    for pattern in prediction_output:
        # pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                new_note = note.Note(int(current_note))
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
        # pattern is a note
        else:
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)

        # increase offset each iteration so that notes do not stack
        offset += 0.5

    midi_stream = stream.Stream(output_notes)

    midi_stream.write('midi', fp=file_path)

# %%
create_midi(prediction_song, '/root/userspace/keras-composer/test_vae_onehot_out_20180929_1.midi')

# %%
decoder_input = np.array([[-0.0001, 0.0001]])
decoder_predicted = model.decoder.predict(decoder_input)

# %%
prediction_indices = np.argmax(decoder_predicted, axis=2)

prediction_song = [int_to_note[index] for index in prediction_indices[0]]
print(prediction_song)
# Out:
# ['D4', 'E4', 'A3', 'C#5', '0.4', '4.7', 'C#5', 'A4', 'G4', '9.2', 'B3', 'F#5', 'G5', 'G3', '11.2', '11.2', 'F#3', 'D5', 'G4', 'A3', 'F#3', 'D3', 'C4', 'C4', 'F#3', '9.0', 'C4', 'B4', 'C5', 'D5', 'G3', 'B4', 'G4', 'D5', 'B4', 'F#5', 'F5', 'C3', 'E5', 'C5', 'A4', 'A5', '2.4', '0.4', '6.9', '7.11', '9.0', 'B2', 'E2', 'A2', 'B2', 'B4', 'G5', 'G5', 'E5', '11.2', '4.7', '6.9', '7.11', 'C#3', 'G5', 'E5', 'D5', 'C3', 'C5', 'D5', 'E3', 'C5', 'D5', 'A3', 'C5', 'D5', 'E3', 'C5', 'D5', 'C5', 'G#3', 'D5', 'C5', 'B2', 'D5', 'D5', 'B2', 'D5', 'G4', 'C3', 'D5', 'C5', 'D5', 'D3', 'C5', 'G5', 'F#3', 'E3', 'C5', 'A3', 'C5', 'D5', 'D4', 'C5', 'D5', 'C5', 'A3', 'D5', 'C5', 'F#3', 'D5', 'C5', 'D3', 'D5', 'B2', 'E3', 'D5', 'C5', 'D5', 'D5', 'C5', 'B4', 'G3', 'C5', 'B4', 'B3', 'C5', 'B4', 'D4', 'C5', 'B4', 'G4', 'C5', 'B4', 'D4', 'C5', 'B4', 'C5', 'B4', 'B4', 'B4', 'B4', 'C5', 'C5', 'C5', 'C5', 'B4', 'B4', 'B3', 'C4', 'B4', 'E-5', 'C5', 'D5', 'G#3', 'C#4', 'B4', 'G3', 'G#3', '0.4', '9.0', '6.9', 'C5', '0.6', '9', '9', 'B4', 'B-3', 'G3', '11.3', 'B4', 'E3', 'C5', 'B4', 'B4', 'G3', 'D3', 'C3', 'D3', 'D3', 'C3', 'C3', 'C3', 'D3', 'D3', 'D3', 'D3', 'D3', 'D3', 'C3', 'D3', 'D3', 'C3', 'C3', 'C3', 'D3', 'D3', 'C3', 'C3', 'D3', 'D3', 'C3', 'C3', 'C3', 'C3', 'D3', 'D3', 'C3', 'C3', 'C3', 'C3', 'C3', 'D3', 'D3', 'D3', 'D3', 'D3', 'D3', 'D3', 'C3', 'C3', 'C3', 'D3', 'D3', 'D3', 'D3', 'C3', 'E4', 'E4', 'E4', 'E4', '2.6', '2.6', '2.6', '2.6', '2.6', '2.6', 'D5', 'D5', 'C5', 'C5', 'C5', '7.11', '7.11', '7.11', '11.2', '11.2', '11.2', '7.11', '7.11', '2.6', '2.6', '2.6', '2.6', '2.6', '2.6', '2.6', '2.6', '2.6', '6.9', '7.11', '7.11', '7.11', '7.11', '7.11', '7.11', '9.0', '11.2', '2.6', '2.6', 'E2', 'E2', 'E2', 'D5', 'D5', 'D5', 'D5', 'D5', 'D5', '11.4', '11.4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'D3', 'D3', 'D3', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'E4', 'E4', 'E4', 'E4', 'G3', 'G3']

# %%
create_midi(prediction_song, '/root/userspace/keras-composer/test_vae_onehot_out_20180929_2.midi')
